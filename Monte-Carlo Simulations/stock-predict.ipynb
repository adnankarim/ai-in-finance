# %%
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd
from scipy.stats import norm
# %matplotlib inline

# %%
# !pip install yfinance

# %%
ticker='PG'
data=pd.DataFrame()
data[ticker] =  yf.download(ticker, start = '2007-01-01')['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                     PG
# Date
# 2007-01-03   40.329430
# 2007-01-04   40.023247
# 2007-01-05   39.679565
# 2007-01-08   39.767036
# 2007-01-09   39.667061
# ...                ...
# 2023-02-06  141.399994
# 2023-02-07  140.020004
# 2023-02-08  138.570007
# 2023-02-09  137.050003
# 2023-02-10  138.259995
#
# [4056 rows x 1 columns]

# %%
log_returns=np.log(1+data.pct_change())

# %%
log_returns.tail()
# Out:
#                   PG
# Date
# 2023-02-06 -0.008521
# 2023-02-07 -0.009807
# 2023-02-08 -0.010410
# 2023-02-09 -0.011030
# 2023-02-10  0.008790

# %%
data.plot(figsize=(10,8))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
log_returns.plot(figsize=(10,8))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
u=log_returns.mean()

# %%
u
# Out:
# PG    0.000304
# dtype: float64

# %%
var=log_returns.var()

# %%
var
# Out:
# PG    0.00014
# dtype: float64

# %%
drift=u-(0.5*var)
drift
# Out:
# PG    0.000234
# dtype: float64

# %%
std_dev=log_returns.std()
std_dev
# Out:
# PG    0.011852
# dtype: float64
